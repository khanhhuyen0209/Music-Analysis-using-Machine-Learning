# %%
# !pip install mirdata
# Out:
# Collecting mirdata
#   Downloading mirdata-1.0.0-py3-none-any.whl.metadata (9.1 kB)
# Collecting chardet>=5.0.0 (from mirdata)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting Deprecated>=1.2.14 (from mirdata)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: h5py>=3.7.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from mirdata) (3.12.1)
# Requirement already satisfied: librosa>=0.10.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from mirdata) (0.11.0)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from mirdata) (2.2.6)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from mirdata) (2.3.3)
# Collecting pretty_midi>=0.2.10 (from mirdata)
#   Downloading pretty_midi-0.2.11.tar.gz (5.6 MB)
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#      - -------------------------------------- 0.3/5.6 MB ? eta -:--:--
#      ---------------------- ----------------- 3.1/5.6 MB 13.2 MB/s eta 0:00:01
#      ---------------------------------------- 5.6/5.6 MB 18.0 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pyyaml>=6.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from mirdata) (6.0.3)
# Collecting openpyxl>=3.0.10 (from mirdata)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from mirdata) (1.14.1)
# Requirement already satisfied: tqdm>=4.66.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from mirdata) (4.67.1)
# Collecting smart_open>=5.0.0 (from smart_open[all]>=5.0.0->mirdata)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt<3,>=1.10 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from Deprecated>=1.2.14->mirdata) (1.14.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (0.62.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (1.5.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from librosa>=0.10.1->mirdata) (1.1.2)
# Requirement already satisfied: packaging in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from lazy_loader>=0.1->librosa>=0.10.1->mirdata) (24.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.51.0->librosa>=0.10.1->mirdata) (0.45.1)
# Collecting et-xmlfile (from openpyxl>=3.0.10->mirdata)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.5->mirdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.5->mirdata) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.5->mirdata) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.1->librosa>=0.10.1->mirdata) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.1->librosa>=0.10.1->mirdata) (2.32.3)
# Collecting mido>=1.1.16 (from pretty_midi>=0.2.10->mirdata)
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: six in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from pretty_midi>=0.2.10->mirdata) (1.16.0)
# Collecting importlib_resources (from pretty_midi>=0.2.10->mirdata)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.1.0->librosa>=0.10.1->mirdata) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from soundfile>=0.12.1->librosa>=0.10.1->mirdata) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.10.1->mirdata) (2.23)
# Requirement already satisfied: colorama in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.66.1->mirdata) (0.4.6)
# Collecting boto3>=1.9.17 (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading boto3-1.42.15-py3-none-any.whl.metadata (6.8 kB)
# Collecting google-cloud-storage>=2.6.0 (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_cloud_storage-3.7.0-py3-none-any.whl.metadata (14 kB)
# Collecting azure-storage-blob (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Collecting azure-common (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting azure-core (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading azure_core-1.37.0-py3-none-any.whl.metadata (47 kB)
# Collecting paramiko (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting backports.zstd>=1.0.0 (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading backports_zstd-1.2.0-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Collecting botocore<1.43.0,>=1.42.15 (from boto3>=1.9.17->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading botocore-1.42.15-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.9.17->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3>=1.9.17->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (2.43.0)
# Collecting google-api-core<3.0.0,>=2.27.0 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_crc32c-1.8.0-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (6.33.1)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading proto_plus-1.27.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\delll\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (0.6.1)
# Collecting cryptography>=2.1.4 (from azure-storage-blob->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting isodate>=0.6.1 (from azure-storage-blob->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting bcrypt>=3.2 (from paramiko->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting invoke>=2.0 (from paramiko->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pynacl>=1.5 (from paramiko->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading pynacl-1.6.1-cp38-abi3-win_amd64.whl.metadata (10 kB)
# Downloading mirdata-1.0.0-py3-none-any.whl (263 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading backports_zstd-1.2.0-cp311-cp311-win_amd64.whl (313 kB)
# Downloading boto3-1.42.15-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.15-py3-none-any.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---------------------------------------- 14.6/14.6 MB 70.6 MB/s  0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading google_cloud_storage-3.7.0-py3-none-any.whl (303 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.8.0-cp311-cp311-win_amd64.whl (34 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading proto_plus-1.27.0-py3-none-any.whl (50 kB)
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_core-1.37.0-py3-none-any.whl (214 kB)
# Downloading azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -------------------------------------- - 3.4/3.5 MB 28.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 9.5 MB/s  0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading paramiko-4.0.0-py3-none-any.whl (223 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading invoke-2.2.1-py3-none-any.whl (160 kB)
# Downloading pynacl-1.6.1-cp38-abi3-win_amd64.whl (238 kB)
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (pyproject.toml): started
#   Building wheel for pretty_midi (pyproject.toml): finished with status 'done'
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.11-py3-none-any.whl size=5595992 sha256=027383f51eb78f38bfcc87dd37841eb358d2a32c3318f08522005be043aa7248
#   Stored in directory: c:\users\delll\appdata\local\pip\cache\wheels\09\e6\e6\29223dbea25e71e517b8791bf35cc9a7b872cb2ad284e30181
# Successfully built pretty_midi
# Installing collected packages: azure-common, smart_open, proto-plus, mido, jmespath, isodate, invoke, importlib_resources, googleapis-common-protos, google-crc32c, et-xmlfile, Deprecated, chardet, bcrypt, backports.zstd, pynacl, pretty_midi, openpyxl, google-resumable-media, cryptography, botocore, azure-core, s3transfer, paramiko, google-api-core, azure-storage-blob, google-cloud-core, boto3, google-cloud-storage, mirdata
#
#    ----------------------------------------  0/30 [azure-common]
#    - --------------------------------------  1/30 [smart_open]
#    - --------------------------------------  1/30 [smart_open]
#    -- -------------------------------------  2/30 [proto-plus]
#    -- -------------------------------------  2/30 [proto-plus]
#    -- -------------------------------------  2/30 [proto-plus]
#    -- -------------------------------------  2/30 [proto-plus]
#    ---- -----------------------------------  3/30 [mido]
#    ---- -----------------------------------  3/30 [mido]
#    ---- -----------------------------------  3/30 [mido]
#    ---- -----------------------------------  3/30 [mido]
#    ---- -----------------------------------  3/30 [mido]
#    ---- -----------------------------------  3/30 [mido]
#    ---- -----------------------------------  3/30 [mido]
#    ---- -----------------------------------  3/30 [mido]
#    ----- ----------------------------------  4/30 [jmespath]
#    ------ ---------------------------------  5/30 [isodate]
#    ------ ---------------------------------  5/30 [isodate]
#    -------- -------------------------------  6/30 [invoke]
#    -------- -------------------------------  6/30 [invoke]
#    -------- -------------------------------  6/30 [invoke]
#    -------- -------------------------------  6/30 [invoke]
#    -------- -------------------------------  6/30 [invoke]
#    -------- -------------------------------  6/30 [invoke]
#    -------- -------------------------------  6/30 [invoke]
#    -------- -------------------------------  6/30 [invoke]
#    --------- ------------------------------  7/30 [importlib_resources]
#    --------- ------------------------------  7/30 [importlib_resources]
#    --------- ------------------------------  7/30 [importlib_resources]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ---------- -----------------------------  8/30 [googleapis-common-protos]
#    ------------ ---------------------------  9/30 [google-crc32c]
#    -------------- ------------------------- 11/30 [Deprecated]
#    ---------------- ----------------------- 12/30 [chardet]
#    ---------------- ----------------------- 12/30 [chardet]
#    ---------------- ----------------------- 12/30 [chardet]
#    ---------------- ----------------------- 12/30 [chardet]
#    ---------------- ----------------------- 12/30 [chardet]
#    ---------------- ----------------------- 12/30 [chardet]
#    ---------------- ----------------------- 12/30 [chardet]
#    ------------------ --------------------- 14/30 [backports.zstd]
#    ------------------ --------------------- 14/30 [backports.zstd]
#    ------------------ --------------------- 14/30 [backports.zstd]
#    -------------------- ------------------- 15/30 [pynacl]
#    -------------------- ------------------- 15/30 [pynacl]
#    -------------------- ------------------- 15/30 [pynacl]
#    -------------------- ------------------- 15/30 [pynacl]
#    --------------------- ------------------ 16/30 [pretty_midi]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ---------------------- ----------------- 17/30 [openpyxl]
#    ------------------------ --------------- 18/30 [google-resumable-media]
#    ------------------------ --------------- 18/30 [google-resumable-media]
#    ------------------------ --------------- 18/30 [google-resumable-media]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    ------------------------- -------------- 19/30 [cryptography]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    -------------------------- ------------- 20/30 [botocore]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ---------------------------- ----------- 21/30 [azure-core]
#    ----------------------------- ---------- 22/30 [s3transfer]
#    ----------------------------- ---------- 22/30 [s3transfer]
#    ------------------------------ --------- 23/30 [paramiko]
#    ------------------------------ --------- 23/30 [paramiko]
#    ------------------------------ --------- 23/30 [paramiko]
#    ------------------------------ --------- 23/30 [paramiko]
#    ------------------------------ --------- 23/30 [paramiko]
#    ------------------------------ --------- 23/30 [paramiko]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    -------------------------------- ------- 24/30 [google-api-core]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    --------------------------------- ------ 25/30 [azure-storage-blob]
#    ---------------------------------- ----- 26/30 [google-cloud-core]
#    ------------------------------------ --- 27/30 [boto3]
#    ------------------------------------ --- 27/30 [boto3]
#    ------------------------------------ --- 27/30 [boto3]
#    ------------------------------------ --- 27/30 [boto3]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    ------------------------------------- -- 28/30 [google-cloud-storage]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    -------------------------------------- - 29/30 [mirdata]
#    ---------------------------------------- 30/30 [mirdata]
#
# Successfully installed Deprecated-1.3.1 azure-common-1.1.28 azure-core-1.37.0 azure-storage-blob-12.27.1 backports.zstd-1.2.0 bcrypt-5.0.0 boto3-1.42.15 botocore-1.42.15 chardet-5.2.0 cryptography-46.0.3 et-xmlfile-2.0.0 google-api-core-2.28.1 google-cloud-core-2.5.0 google-cloud-storage-3.7.0 google-crc32c-1.8.0 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 importlib_resources-6.5.2 invoke-2.2.1 isodate-0.7.2 jmespath-1.0.1 mido-1.3.3 mirdata-1.0.0 openpyxl-3.1.5 paramiko-4.0.0 pretty_midi-0.2.11 proto-plus-1.27.0 pynacl-1.6.1 s3transfer-0.16.0 smart_open-7.5.0
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\DELLL\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\DELLL\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\DELLL\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
#@title Import libraries
import numpy as np
import librosa
import mirdata
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler

# Audio config
SR = 22050
N_FFT = 1024
HOP_LENGTH = 256          # ~11.6 ms
N_MELS = 64
FMIN = 80
FMAX = 2000               # guitar range

# Pitch config
UNVOICED = 0              # class 0
MIDI_MIN = 40             # E2
MIDI_MAX = 88             # E6
N_PITCH_CLASS = MIDI_MAX - MIDI_MIN + 2  # + unvoiced
MAX_TRACKS = None         # set số nhỏ nếu test

# %%
#@title Load dataset
gset = mirdata.initialize("guitarset")
gset.download()

track_ids = gset.track_ids
if MAX_TRACKS:
    track_ids = track_ids[:MAX_TRACKS]
# Out:
# WARNING:root:Downloading ['annotations', 'audio_hex_debleeded', 'audio_hex_original', 'audio_mic', 'audio_mix', 'index']. Index is being stored in /usr/local/lib/python3.12/dist-packages/mirdata/datasets/indexes, and the rest of files in /root/mir_datasets/guitarset
# WARNING:root:[annotations] downloading annotation.zip
# 37.3MB [00:34, 1.12MB/s]
# WARNING:root:[audio_hex_debleeded] downloading audio_hex-pickup_debleeded.zip
# 3.36GB [18:08, 3.31MB/s]
# WARNING:root:[audio_hex_original] downloading audio_hex-pickup_original.zip
# 2.99GB [17:33, 3.05MB/s]
# WARNING:root:[audio_mic] downloading audio_mono-mic.zip
# 626MB [05:42, 1.92MB/s]
# WARNING:root:[audio_mix] downloading audio_mono-pickup_mix.zip
# 652MB [02:02, 5.56MB/s]
# WARNING:root:[index] downloading guitarset_index_1.1.0.json
# 248kB [00:01, 189kB/s]

# %%
#@title Helper functions
def extract_logmel(y, sr):
    mel = librosa.feature.melspectrogram(
        y=y,
        sr=sr,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        n_mels=N_MELS,
        fmin=FMIN,
        fmax=FMAX,
        power=2.0
    )
    mel_db = librosa.power_to_db(mel, ref=np.max)
    return mel_db.T   # (T_frames, n_mels)

def get_frame_times(n_frames, sr, hop_length):
    """Time (seconds) of each mel frame"""
    return np.arange(n_frames) * hop_length / sr

STRINGS = ["E", "A", "D", "G", "B", "e"]

def extract_mono_pitch_midi(track):
    pcs = track.pitch_contours

    # ---- chọn timeline tham chiếu ----
    ref_times = None
    for s in STRINGS:
        if pcs.get(s) is not None:
            ref_times = pcs[s].times
            break

    if ref_times is None:
        # không có pitch annotation nào
        return np.array([]), np.array([])

    pitch_strings = []

    for s in STRINGS:
        f0data = pcs.get(s)

        if f0data is None:
            # dây không có annotation → unvoiced
            f0_aligned = np.zeros_like(ref_times)
        else:
            f0 = f0data.frequencies
            times = f0data.times

            # align về ref_times
            f0_aligned = np.interp(
                ref_times,
                times,
                f0,
                left=0.0,
                right=0.0
            )

        pitch_strings.append(f0_aligned)

    pitches = np.stack(pitch_strings, axis=0)   # (<=6, T)
    mono_hz = np.max(pitches, axis=0)

    midi = np.zeros_like(mono_hz, dtype=np.float32)
    voiced = mono_hz > 0
    midi[voiced] = 69 + 12 * np.log2(mono_hz[voiced] / 440.0)

    return ref_times, midi

def align_pitch_to_frames(pitch_times, midi, frame_times):
    """
    Interpolate pitch contour to mel-frame timeline
    """
    return np.interp(
        frame_times,
        pitch_times,
        midi,
        left=0.0,
        right=0.0
    )

def midi_to_class(midi):
    """
    0 = unvoiced
    1..N = pitch classes
    """
    midi = np.round(midi).astype(int)
    cls = np.zeros_like(midi, dtype=np.int32)
    voiced = (midi >= MIDI_MIN) & (midi <= MIDI_MAX)
    cls[voiced] = midi[voiced] - MIDI_MIN + 1
    return cls

def extract_tempo(track, n_frames):
    """
    GuitarSet tempo is global (BPM).
    Handle all known GuitarSet API variants.
    """
    tempo_ann = track.tempo

    if tempo_ann is None:
        return np.zeros(n_frames, dtype=np.float32)

    # Case 1: tempo is a float
    if isinstance(tempo_ann, (int, float)):
        bpm = float(tempo_ann)
        return np.full(n_frames, bpm, dtype=np.float32)

    # Case 2: tempo is list-like (annotation)
    try:
        if len(tempo_ann) == 0:
            return np.zeros(n_frames, dtype=np.float32)
        bpm = tempo_ann[0].value
        return np.full(n_frames, bpm, dtype=np.float32)
    except TypeError:
        # fallback safety
        return np.zeros(n_frames, dtype=np.float32)

# %%
#@title Create Pitch + Tempo dataset (frame-level)
X = []
y_pitch = []
y_tempo = []

for tid in tqdm(track_ids):
    track = gset.track(tid)
    if track.audio_mic_path is None:
        continue
    y, sr = librosa.load(track.audio_mic_path, sr=SR, mono=True)
    mel = extract_logmel(y, sr)                     # (T_frames, n_mels)
    frame_times = get_frame_times(len(mel), sr, HOP_LENGTH)
    pitch_times, midi = extract_mono_pitch_midi(track)
    midi_frame = align_pitch_to_frames(
        pitch_times,
        midi,
        frame_times
    )
    pitch_cls = midi_to_class(midi_frame)
    tempo = extract_tempo(track, len(mel))
    X.append(mel)
    y_pitch.append(pitch_cls)
    y_tempo.append(tempo)
# Out:
# 100%|██████████| 360/360 [03:02<00:00,  1.98it/s]

# %%
#@title Scale and normalize
X = np.vstack(X)                # (N, n_mels)
y_pitch = np.concatenate(y_pitch)
y_tempo = np.concatenate(y_tempo)

print("X:", X.shape)
print("Pitch:", y_pitch.shape)
print("Tempo:", y_tempo.shape)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# X: (944904, 64)
# Pitch: (944904,)
# Tempo: (944904,)

# %%
#@title Save dataset (frame-level)
X = X.astype(np.float32)
y_pitch = y_pitch.astype(np.int32)
y_tempo = y_tempo.astype(np.float32)

np.savez_compressed(
    "pitch_tempo.npz",
    X=X,
    pitch=y_pitch,
    tempo=y_tempo
)

print("Saved pitch_tempo.npz")
# Out:
# Saved pitch_tempo.npz

# %%
#@title Onset-based tempo feature

import librosa
import numpy as np

N_ACF = 200  # số lag giữ lại (quan trọng)

def extract_onset_acf_feature(y, sr):
    onset_env = librosa.onset.onset_strength(
        y=y,
        sr=sr,
        hop_length=HOP_LENGTH
    )  # (T,)

    # Autocorrelation
    acf = np.correlate(onset_env, onset_env, mode="full")
    acf = acf[len(acf)//2:]  # keep positive lags

    acf = acf[:N_ACF]
    acf = acf / (np.max(acf) + 1e-6)  # normalize

    return acf  # (N_ACF,)

# %%
#@title Build onset-tempo dataset

X_temp = []
y_temp = []

for tid in tqdm(track_ids):
    track = gset.track(tid)

    if track.audio_mic_path is None or track.tempo is None:
        continue

    y, sr = librosa.load(
        track.audio_mic_path,
        sr=SR,
        mono=True
    )

    feat = extract_onset_acf_feature(y, sr)

    X_temp.append(feat)
    y_temp.append(float(track.tempo))

X_temp = np.stack(X_temp)
y_temp = np.array(y_temp, dtype=np.float32)

print("X_temp:", X_temp.shape)
print("y_temp:", y_temp.shape)
# Out:
# 100%|██████████| 360/360 [00:53<00:00,  6.74it/s]
# X_temp: (360, 200)
# y_temp: (360,)

# %%
#@title Save onset dataset

np.savez(
    "tempo_onset_dataset.npz",
    X=X_temp,          # raw ACF feature
    y=y_temp,          # float BPM
    y_cls=y_cls        # quantized class
)

print("Onset tempo dataset saved to tempo_onset_dataset.npz")
# Out:
# Onset tempo dataset saved to tempo_onset_dataset.npz

# %%
#@title Load dataset
import numpy as np
data = np.load("tempo_onset_dataset.npz")
X_temp = data["X"]
y_temp = data["y"]
y_cls = data["y_cls"]
print(X.shape, y.shape, y_cls.shape)
# Out:
# (360, 200) (360,) (360,)

# %%
#@title Tempo quantization

TEMPO_MIN = 40
TEMPO_MAX = 200

y_cls = np.clip(
    np.round(y_temp),
    TEMPO_MIN,
    TEMPO_MAX
).astype(int)

y_cls = y_cls - TEMPO_MIN  # class index

N_TEMPO_CLASS = TEMPO_MAX - TEMPO_MIN + 1
print("Tempo classes:", N_TEMPO_CLASS)
# Out:
# Tempo classes: 161

# %%
#@title Scale & split

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X_s = scaler.fit_transform(X_temp)

X_tr, X_va, y_tr, y_va = train_test_split(
    X_s,
    y_cls,
    test_size=0.2,
    random_state=42
)

# %%
#@title Train tempo LR

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import numpy as np

clf = LogisticRegression(
    max_iter=3000,
    n_jobs=-1,
    class_weight="balanced"
)

clf.fit(X_tr, y_tr)

pred = clf.predict(X_va)

tempo_pred = pred + TEMPO_MIN
tempo_gt   = y_va + TEMPO_MIN

mae = np.mean(np.abs(tempo_pred - tempo_gt))

print("Tempo ACC:", accuracy_score(y_va, pred))
print("Tempo MAE (BPM):", mae)
# Out:
# Tempo ACC: 0.8055555555555556
# Tempo MAE (BPM): 6.833333333333333

# %%
#@title Finetuning LR for tempo
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import numpy as np

C_list = [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]
best_acc = -1
best_C = None
best_clf = None

for C_val in C_list:
    clf = LogisticRegression(
        C=C_val,
        max_iter=3000,
        n_jobs=-1,
        class_weight="balanced"
    )
    clf.fit(X_tr, y_tr)
    pred = clf.predict(X_va)
    acc = accuracy_score(y_va, pred)
    print(f"C={C_val}, Val ACC={acc:.4f}")

    if acc > best_acc:
        best_acc = acc
        best_C = C_val
        best_clf = clf

print(f"\nBest C: {best_C}, Val ACC: {best_acc:.4f}")
# Out:
# C=0.01, Val ACC=0.7500
# C=0.1, Val ACC=0.8194
# C=0.5, Val ACC=0.7917
# C=1.0, Val ACC=0.8056
# C=5.0, Val ACC=0.8056
# C=10.0, Val ACC=0.8056
#
# Best C: 0.1, Val ACC: 0.8194

# %%
#@title Export best tempo LR to .h

HEADER_FILE = "tempo_lr_model.h"
PREFIX = "TEMPO_LR"

W = best_clf.coef_          # (n_class, N_ACF)
b = best_clf.intercept_     # (n_class,)
n_class, n_feat = W.shape

with open(HEADER_FILE, "w") as f:
    f.write("#pragma once\n\n")
    f.write("#include <stdint.h>\n\n")

    f.write(f"#define {PREFIX}_N_CLASS {n_class}\n")
    f.write(f"#define {PREFIX}_N_FEAT  {n_feat}\n\n")

    # weights
    f.write(f"const float {PREFIX}_W[{PREFIX}_N_CLASS][{PREFIX}_N_FEAT] = {{\n")
    for k in range(n_class):
        row = ", ".join([f"{w:.6f}f" for w in W[k]])
        f.write("  { " + row + " },\n")
    f.write("};\n\n")

    # bias
    f.write(f"const float {PREFIX}_B[{PREFIX}_N_CLASS] = {{\n")
    f.write("  " + ", ".join([f"{x:.6f}f" for x in b]) + "\n")
    f.write("};\n\n")

    # scaler for input
    f.write(f"const float {PREFIX}_MEAN[{PREFIX}_N_FEAT] = {{\n")
    f.write("  " + ", ".join([f"{m:.6f}f" for m in scaler.mean_]) + "\n")
    f.write("};\n\n")

    f.write(f"const float {PREFIX}_SCALE[{PREFIX}_N_FEAT] = {{\n")
    f.write("  " + ", ".join([f"{s:.6f}f" for s in scaler.scale_]) + "\n")
    f.write("};\n")

print(f"Exported multiclass tempo LR to {HEADER_FILE}")
# Out:
# Exported multiclass tempo LR to tempo_lr_model.h
